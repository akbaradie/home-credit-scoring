# %% [markdown]
# <a href="https://colab.research.google.com/github/akbaradie/home-credit-scoring/blob/main/HC_Bureau.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_columns = 200
pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip 'drive/My Drive/Career/Internship/Rakamin Academy/01 Home Credit Indonesia Batch Jan 2024/Week 04/Final Project/home-credit-default-risk.zip' -d 'data/'
# Out:
# Archive:  drive/My Drive/Career/Internship/Rakamin Academy/01 Home Credit Indonesia Batch Jan 2024/Week 04/Final Project/home-credit-default-risk.zip
#   inflating: data/HomeCredit_columns_description.csv
#   inflating: data/POS_CASH_balance.csv
#   inflating: data/application_test.csv
#   inflating: data/application_train.csv
#   inflating: data/bureau.csv
#   inflating: data/bureau_balance.csv
#   inflating: data/credit_card_balance.csv
#   inflating: data/installments_payments.csv
#   inflating: data/previous_application.csv
#   inflating: data/sample_submission.csv

# %% [markdown]
# ## Data Wrangling

# %%
df_bureau= pd.read_csv('data/bureau.csv')
print('data shape:',df_bureau.shape)
df_bureau.head()
# Out:
# data shape: (1716428, 17)
#    SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0      215354       5714462        Closed      currency 1         -497
# 1      215354       5714463        Active      currency 1         -208
# 2      215354       5714464        Active      currency 1         -203
# 3      215354       5714465        Active      currency 1         -203
# 4      215354       5714466        Active      currency 1         -629
#
#    CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 0                   0             -153.000           -153.000
# 1                   0             1075.000                NaN
# 2                   0              528.000                NaN
# 3                   0                  NaN                NaN
# 4                   0             1197.000                NaN
#
#    AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 0                     NaN                   0       91323.000
# ...

# %%
df_bureaubal= pd.read_csv('data/bureau.csv')
print('data shape:',df_bureaubal.shape)
df_bureau.head()
# Out:
# data shape: (1716428, 17)
#    SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0      215354       5714462        Closed      currency 1         -497
# 1      215354       5714463        Active      currency 1         -208
# 2      215354       5714464        Active      currency 1         -203
# 3      215354       5714465        Active      currency 1         -203
# 4      215354       5714466        Active      currency 1         -629
#
#    CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 0                   0             -153.000           -153.000
# 1                   0             1075.000                NaN
# 2                   0              528.000                NaN
# 3                   0                  NaN                NaN
# 4                   0             1197.000                NaN
#
#    AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 0                     NaN                   0       91323.000
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA) Bureau

# %%
df_bureau.isna().sum()
# Out:
# SK_ID_CURR                      0
# SK_ID_BUREAU                    0
# CREDIT_ACTIVE                   0
# CREDIT_CURRENCY                 0
# DAYS_CREDIT                     0
# CREDIT_DAY_OVERDUE              0
# DAYS_CREDIT_ENDDATE        105553
# DAYS_ENDDATE_FACT          633653
# AMT_CREDIT_MAX_OVERDUE    1124488
# CNT_CREDIT_PROLONG              0
# AMT_CREDIT_SUM                 13
# AMT_CREDIT_SUM_DEBT        257669
# AMT_CREDIT_SUM_LIMIT       591780
# AMT_CREDIT_SUM_OVERDUE          0
# CREDIT_TYPE                     0
# DAYS_CREDIT_UPDATE              0
# AMT_ANNUITY               1226791
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis (EDA) Bureau Balance

# %%
df_bureaubal.isna().sum()
# Out:
# SK_ID_CURR                      0
# SK_ID_BUREAU                    0
# CREDIT_ACTIVE                   0
# CREDIT_CURRENCY                 0
# DAYS_CREDIT                     0
# CREDIT_DAY_OVERDUE              0
# DAYS_CREDIT_ENDDATE        105553
# DAYS_ENDDATE_FACT          633653
# AMT_CREDIT_MAX_OVERDUE    1124488
# CNT_CREDIT_PROLONG              0
# AMT_CREDIT_SUM                 13
# AMT_CREDIT_SUM_DEBT        257669
# AMT_CREDIT_SUM_LIMIT       591780
# AMT_CREDIT_SUM_OVERDUE          0
# CREDIT_TYPE                     0
# DAYS_CREDIT_UPDATE              0
# AMT_ANNUITY               1226791
# dtype: int64
